# %% [markdown]
# # 1. Why SQL is Important to Learn

# %% [markdown]
# **Here are a few key reasons why learning SQL is beneficial to anybody that is interested in working with data:**

# %% [markdown]
# **SQL is everywhere**
#
# Almost all of the biggest names in tech use SQL — which is pronounced either “sequel” or “S.Q.L.”, by the way. Companies like Facebook, Google, and Amazon have built their own high-performance database systems, but even their data teams use SQL to query data and perform data analysis. And it’s not just tech companies: companies big and small around the globe use SQL.

# %% [markdown]
# **SQL enables us to pull data from many sources**
#
# In many real-word situations, data is spread across many sources. Using SQL allows us to select specific data and transform it to fit our needs. For example, working with spreadsheets can be difficult if the data we need to answer our question is spread across many files. SQL allows us to structure our data in a way that makes all of our data accessible from one place.

# %% [markdown]
# **`SQL data is structured into multiple, connected tables.`**

# %% [markdown]
# **SQL is here to stay**
#
# As mentioned above, SQL is one of the most popular tools used by data professionals. The Stack Overflow annual Developer Survey, which is the largest and most comprehensive survey of programmers around the world, consistently reveals that SQL is one of the most popular technologies used today.

# %% [markdown]
# # 2. Introduction to Databases

# %% [markdown]
# When we work with data stored on our computers, we load the data from files like spreadsheets (and text files in several different formats). Working with files solely on our computer is fine for most occasions, but we run into problems when we consider a few questions:
#
# * What if the data is **too big** to fit into a single spreadsheet file?
# * What if you share the data with team members and **keep it updated**?
# * What if there's sensitive information in your data that **needs protection**?

# %% [markdown]
# **A database** structures data much like how we would see it in a spreadsheet file, where data is organized in different tables which in turn are organized into rows and columns

# %% [markdown]
# **A database is capable of storing much more data and in a more secure way than a spreadsheet or text file. Unlike opening a spreadsheet, we actually have to "ask" for data from the database in order to visualize it.**

# %% [markdown]
# * We primarily interact with a database using a [database management system (DBMS)](https://en.wikipedia.org/wiki/Database) — a computer program to help users interact with data. Users can do this by by giving the computer instructions through the DBMS.
#
# * We'll start learning SQL with the DBMS [SQLite](https://www.sqlite.org/index.html). SQLite is a lightweight DBMS and is the most popular database in the world

# %% [markdown]
# # 3. Your First Query

# %% [markdown]
# In this course, we'll explore data from the American Community Survey on job outcome statistics based on college majors that we loaded into a SQLite database.

# %% [markdown]
# Head to the [dataset page](https://github.com/fivethirtyeight/data/tree/master/college-majors) and spend some time getting familiar with what each column represents.
#
# We provide a database, jobs.db, loaded with these data into a single table named recent_grads (in the next course, we'll learn how to work with a database containing multiple tables.)

# %%
# %load_ext sql

# %%
# %sql sqlite:///jobs.db

# %%
# %%sql
#
# SELECT *
# FROM recent_grads;
# Out:
#  * sqlite:///jobs.db
# Done.
# [(0, 1, 2419, 'PETROLEUM ENGINEERING', 'Engineering', 2339, 36, 2057, 282, 0.120564344, 1976, 1849, 270, 1207, 37, 0.018380527, 110000, 95000, 125000, 1534, 364, 193),
#  (1, 2, 2416, 'MINING AND MINERAL ENGINEERING', 'Engineering', 756, 7, 679, 77, 0.10185185199999999, 640, 556, 170, 388, 85, 0.117241379, 75000, 55000, 90000, 350, 257, 50),
#  (2, 3, 2415, 'METALLURGICAL ENGINEERING', 'Engineering', 856, 3, 725, 131, 0.153037383, 648, 558, 133, 340, 16, 0.024096386, 73000, 50000, 105000, 456, 176, 0),
#  (164, 165, 2307, 'EARLY CHILDHOOD EDUCATION', 'Education', 37589, 342, 1225, 37054, 0.9679981190000001, 32551, 27569, 7001, 20748, 1360, 0.040104981, 28000, 21000, 35000, 23515, 7705, 2868),
#  (165, 166, 2603, 'OTHER FOREIGN LANGUAGES', 'Humanities & Liberal Arts', 11204, 56, 3472, 7732, 0.690110675, 7052, 5197, 3685, 3214, 846, 0.107115726, 27500, 22900, 38000, 2326, 3703, 1115),
#  (166, 167, 6001, 'DRAMA AND THEATER ARTS', 'Arts', 43249, 357, 7022, 11931, 0.629504564, 36165, 25147, 15994, 16891, 3040, 0.07754113, 27000, 19200, 35000, 6994, 25313, 11068),
#  (167, 168, 3302, 'COMPOSITION AND RHETORIC', 'Humanities & Liberal Arts', 18953, 151, 14440, 28809, 0.666119448, 15053, 10121, 6612, 7832, 1340, 0.081742207, 27000, 20000, 35000, 4855, 8100, 3466),
#  (168, 169, 3609, 'ZOOLOGY', 'Biology & Life Science', 8409, 47, 3050, 5359, 0.637293376, 6259, 5043, 2190, 3602, 304, 0.04632028, 26000, 20000, 39000, 2771, 2947, 743),
#  (169, 170, 5201, 'EDUCATIONAL PSYCHOLOGY', 'Psychology & Social Work', 2854, 7, 522, 2332, 0.8170988090000001, 2125, 1848, 572, 1211, 148, 0.065112187, 25000, 24000, 34000, 1488, 615, 82),
#  (170, 171, 5202, 'CLINICAL PSYCHOLOGY', 'Psychology & Social Work', 2838, 13, 568, 2270, 0.799859056, 2101, 1724, 648, 1293, 368, 0.14904819800000002, 25000, 25000, 40000, 986, 870, 622),
#  (171, 172, 5203, 'COUNSELING PSYCHOLOGY', 'Psychology & Social Work', 4626, 21, 931, 3695, 0.798746217, 3777, 3154, 965, 2738, 214, 0.053620645999999994, 23400, 19200, 26000, 2403, 1245, 308),
#  (172, 173, 3501, 'LIBRARY SCIENCE', 'Education', 1098, 2, 134, 964, 0.877959927, 742, 593, 237, 410, 87, 0.10494571800000001, 22000, 20000, 22000, 288, 338, 192)]

# %% [markdown]
# # 4. Understanding your First Query

# %% [markdown]
# The process by which you were able to visualize recent_grads can be broken down into two seps:
#
# * Write a SQL query that expresses the request "fetch all the data in the table".
# * Ask the SQLite DBMS software to run the code and display the results.

# %%
from IPython.display import Image
Image(url='https://s3.amazonaws.com/dq-content/252/select_breakdown.svg')
# Out:
# <img src="https://s3.amazonaws.com/dq-content/252/select_breakdown.svg"/>

# %% [markdown]
# * SELECT and FROM are written in uppercase letters. This isn't required by the syntax, but it helps with making your code easier to read.

# %% [markdown]
# # 5. Previewing a Table

# %% [markdown]
# You may also have noticed that this table has 173 rows and over 20 columns. For a computer, these aren't that many rows, nor that many columns. For a human, however, it's hard to make sense of these much data.

# %% [markdown]
# In the following missions and in the next course we'll learn how to make sense of large amounts of data using SQL. For now, we'll focus on how we can preview of a table without displaying it completely in the screen.
#
# In practice, you will often find yourself having access to a database with no documentation. In this situation, you'll have to rely on the surrounding context of the database and on your exploration of it.

# %% [markdown]
# # 6. The LIMIT Clause

# %% [markdown]
# * SQL is a database dependent language. This means that the SQL that you're learning here (for SQLite) is not the same as SQL for other DBMSs like PostgreSQL or Oracle.
# * The main takeaway is that different SQL dialects exist and we should watchout for differences when switching between DBMSs.

# %% [markdown]
# **Write a SQL query that returns the first five rows from recent_grads.***

# %%
# %%sql
#
# SELECT *
# FROM recent_grads
# LIMIT 5;
# Out:
#  * sqlite:///jobs.db
# Done.
# [(0, 1, 2419, 'PETROLEUM ENGINEERING', 'Engineering', 2339, 36, 2057, 282, 0.120564344, 1976, 1849, 270, 1207, 37, 0.018380527, 110000, 95000, 125000, 1534, 364, 193),
#  (1, 2, 2416, 'MINING AND MINERAL ENGINEERING', 'Engineering', 756, 7, 679, 77, 0.10185185199999999, 640, 556, 170, 388, 85, 0.117241379, 75000, 55000, 90000, 350, 257, 50),
#  (2, 3, 2415, 'METALLURGICAL ENGINEERING', 'Engineering', 856, 3, 725, 131, 0.153037383, 648, 558, 133, 340, 16, 0.024096386, 73000, 50000, 105000, 456, 176, 0),
#  (3, 4, 2417, 'NAVAL ARCHITECTURE AND MARINE ENGINEERING', 'Engineering', 1258, 16, 1123, 135, 0.107313196, 758, 1069, 150, 692, 40, 0.050125313, 70000, 43000, 80000, 529, 102, 0),
#  (4, 5, 2405, 'CHEMICAL ENGINEERING', 'Engineering', 32260, 289, 21239, 11021, 0.341630502, 25694, 23170, 5180, 16697, 1672, 0.061097712, 65000, 50000, 75000, 18314, 4440, 972)]

# %% [markdown]
# # 7. Selecting Specific Columns

# %% [markdown]
# Notice that we use commas to separate column names, and that after the last column name there is no comma. When SQL finds a comma, it expects a column to follow, so we need to make sure we don't include a comma after the last column.

# %% [markdown]
# **Write a SQL query that returns only the Major and ShareWomen columns (in that order).**

# %%
# %%sql
#
# SELECT Major,ShareWomen
# FROM recent_grads
# Out:
#  * sqlite:///jobs.db
# Done.
# [('PETROLEUM ENGINEERING', 0.120564344),
#  ('MINING AND MINERAL ENGINEERING', 0.10185185199999999),
#  ('METALLURGICAL ENGINEERING', 0.153037383),
#  ('NAVAL ARCHITECTURE AND MARINE ENGINEERING', 0.107313196),
#  ('CHEMICAL ENGINEERING', 0.341630502),
#  ('NUCLEAR ENGINEERING', 0.144966965),
#  ('ACTUARIAL SCIENCE', 0.535714286),
#  ('ASTRONOMY AND ASTROPHYSICS', 0.44135557299999995),
#  ('MECHANICAL ENGINEERING', 0.139792801),
#  ('ELECTRICAL ENGINEERING', 0.437846874),
#  ('COMPUTER ENGINEERING', 0.199412643),
#  ('AEROSPACE ENGINEERING', 0.19645025600000002),
#  ('BIOMEDICAL ENGINEERING', 0.11955890300000001),
#  ('MATERIALS SCIENCE', 0.310820285),
#  ('ENGINEERING MECHANICS PHYSICS AND SCIENCE', 0.183985189),
#  ('BIOLOGICAL ENGINEERING', 0.32078431399999996),
#  ('INDUSTRIAL AND MANUFACTURING ENGINEERING', 0.34347321799999997),
#  ('GENERAL ENGINEERING', 0.252959838),
#  ('ARCHITECTURAL ENGINEERING', 0.35044247799999995),
#  ('COURT REPORTING', 0.236062718),
#  ('COMPUTER SCIENCE', 0.578766338),
#  ('FOOD SCIENCE', 0.222695002),
#  ('ELECTRICAL ENGINEERING TECHNOLOGY', 0.325091881),
#  ('MATERIALS ENGINEERING AND MATERIALS SCIENCE', 0.292607004),
#  ('MANAGEMENT INFORMATION SYSTEMS AND STATISTICS', 0.278790146),
#  ('CIVIL ENGINEERING', 0.22711794300000002),
#  ('CONSTRUCTION SERVICES', 0.342228811),
#  ('OPERATIONS LOGISTICS AND E-COMMERCE', 0.322222222),
#  ('MISCELLANEOUS ENGINEERING', 0.189970437),
#  ('PUBLIC POLICY', 0.251388889),
#  ('ENVIRONMENTAL ENGINEERING', 0.558548009),
#  ('ENGINEERING TECHNOLOGIES', 0.09071250900000001),
#  ('MISCELLANEOUS FINE ARTS', 0.41017964100000004),
#  ('GEOLOGICAL AND GEOPHYSICAL ENGINEERING', 0.32483805),
#  ('NURSING', 0.896018988),
#  ('FINANCE', 0.355469059),
#  ('ECONOMICS', 0.34082495700000004),
#  ('BUSINESS ECONOMICS', 0.24919024),
#  ('INDUSTRIAL PRODUCTION TECHNOLOGIES', 0.75047259),
#  ('NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL TECHNOLOGIES', 0.430536761),
#  ('ACCOUNTING', 0.253583302),
#  ('MATHEMATICS', 0.24410308100000003),
#  ('COMPUTER AND INFORMATION SYSTEMS', 0.7077185020000001),
#  ('PHYSICS', 0.448098678),
#  ('MEDICAL TECHNOLOGIES TECHNICIANS', 0.43429844100000004),
#  ('INFORMATION SCIENCES', 0.526475764),
#  ('STATISTICS AND DECISION SCIENCE', 0.281936407),
#  ('APPLIED MATHEMATICS', 0.75392736),
#  ('PHARMACOLOGY', 0.524152583),
#  ('OCEANOGRAPHY', 0.688999173),
#  ('ENGINEERING AND INDUSTRIAL MANAGEMENT', 0.174122505),
#  ('MEDICAL ASSISTING SERVICES', 0.178981938),
#  ('MATHEMATICS AND COMPUTER SCIENCE', 0.927807246),
#  ('COMPUTER PROGRAMMING AND DATA PROCESSING', 0.269193858),
#  ('COGNITIVE SCIENCE AND BIOPSYCHOLOGY', 0.854523227),
#  ('SCHOOL STUDENT COUNSELING', 0.56486557),
#  ('INTERNATIONAL RELATIONS', 0.632986838),
#  ('GENERAL BUSINESS', 0.4179248),
#  ('ARCHITECTURE', 0.321769663),
#  ('INTERNATIONAL BUSINESS', 0.28290282899999997),
#  ('PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTRATION', 0.451464886),
#  ('MOLECULAR BIOLOGY', 0.07745302700000001),
#  ('MISCELLANEOUS BUSINESS & MEDICAL ADMINISTRATION', 0.200022717),
#  ('AGRICULTURE PRODUCTION AND MANAGEMENT', 0.59420765),
#  ('GENERAL AGRICULTURE', 0.515543329),
#  ('MISCELLANEOUS ENGINEERING TECHNOLOGIES', 0.0),
#  ('MECHANICAL ENGINEERING RELATED TECHNOLOGIES', 0.377437326),
#  ('GENETICS', 0.643331121),
#  ('MISCELLANEOUS SOCIAL SCIENCES', 0.5434054220000001),
#  ('UNITED STATES HISTORY', 0.6307163179999999),
#  ('INDUSTRIAL AND ORGANIZATIONAL PSYCHOLOGY', 0.43630163299999997),
#  ('AGRICULTURAL ECONOMICS', 0.589711902),
#  ('PHYSICAL SCIENCES', 0.42692372),
#  ('MILITARY TECHNOLOGIES', 0.429684963),
#  ('CHEMISTRY', 0.5051405379999999),
#  ('ELECTRICAL, MECHANICAL, AND PRECISION TECHNOLOGIES AND PRODUCTION', 0.23244353199999998),
#  ('BUSINESS MANAGEMENT AND ADMINISTRATION', 0.580948004),
#  ('MARKETING AND MARKETING RESEARCH', 0.382900433),
#  ('POLITICAL SCIENCE AND GOVERNMENT', 0.485929877),
#  ('GEOGRAPHY', 0.473189524),
#  ('MICROBIOLOGY', 0.615727227),
#  ('COMPUTER ADMINISTRATION MANAGEMENT AND SECURITY', 0.180882718),
#  ('BIOCHEMICAL SCIENCES', 0.515406449),
#  ('BOTANY', 0.52896915),
#  ('COMPUTER NETWORKING AND TELECOMMUNICATIONS', 0.305004597),
#  ('GEOLOGY AND EARTH SCIENCE', 0.470196865),
#  ('HUMAN RESOURCES AND PERSONNEL MANAGEMENT', 0.672161443),
#  ('PRE-LAW AND LEGAL STUDIES', 0.591001011),
#  ('MISCELLANEOUS HEALTH MEDICAL PROFESSIONS', 0.702020202),
#  ('PUBLIC ADMINISTRATION', 0.47646118299999995),
#  ('GEOSCIENCES', 0.881293889),
#  ('SOCIAL PSYCHOLOGY', 0.7475609259999999),
#  ('ENVIRONMENTAL SCIENCE', 0.584556133),
#  ('COMMUNICATIONS', 0.305109489),
#  ('CRIMINAL JUSTICE AND FIRE PROTECTION', 0.125034655),
#  ('COMMERCIAL ART AND GRAPHIC DESIGN', 0.37435562299999997),
#  ('JOURNALISM', 0.719858952),
#  ('MULTI-DISCIPLINARY OR GENERAL SCIENCE', 0.669998505),
#  ('ADVERTISING AND PUBLIC RELATIONS', 0.6731433920000001),
#  ('AREA ETHNIC AND CIVILIZATION STUDIES', 0.758060269),
#  ('SPECIAL NEEDS EDUCATION', 0.366176878),
#  ('PHYSIOLOGY', 0.9066773370000001),
#  ('CRIMINOLOGY', 0.618223028),
#  ('NUTRITION SCIENCES', 0.63814682),
#  ('HEALTH AND MEDICAL ADMINISTRATIVE SERVICES', 0.770901106),
#  ('COMMUNICATION TECHNOLOGIES', 0.8644560790000001),
#  ('TRANSPORTATION SCIENCES AND TECHNOLOGIES', 0.321296067),
#  ('NATURAL RESOURCES MANAGEMENT', 0.564639335),
#  ('NEUROSCIENCE', 0.47501047),
#  ('MULTI/INTERDISCIPLINARY STUDIES', 0.495397153),
#  ('ATMOSPHERIC SCIENCES AND METEOROLOGY', 0.124950495),
#  ('FORESTRY', 0.690365288),
#  ('SOIL SCIENCE', 0.764426528),
#  ('GENERAL EDUCATION', 0.8128766059999999),
#  ('HISTORY', 0.651741294),
#  ('FRENCH GERMAN LATIN AND OTHER COMMON FOREIGN LANGUAGE STUDIES', 0.728032591),
#  ('INTERCULTURAL AND INTERNATIONAL STUDIES', 0.507376968),
#  ('SOCIAL SCIENCE OR HISTORY TEACHER EDUCATION', 0.733967583),
#  ('COMMUNITY AND PUBLIC HEALTH', 0.6521298170000001),
#  ('MATHEMATICS TEACHER EDUCATION', 0.792095262),
#  ('EDUCATIONAL ADMINISTRATION AND SUPERVISION', 0.448732309),
#  ('HEALTH AND MEDICAL PREPARATORY PROGRAMS', 0.5566037739999999),
#  ('MISCELLANEOUS BIOLOGY', 0.566640502),
#  ('BIOLOGY', 0.601858152),
#  ('SOCIOLOGY', 0.532333788),
#  ('MASS MEDIA', 0.8772275279999999),
#  ('TREATMENT THERAPY PROFESSIONS', 0.64),
#  ('HOSPITALITY MANAGEMENT', 0.733991928),
#  ('LANGUAGE AND DRAMA EDUCATION', 0.576360061),
#  ('LINGUISTICS AND COMPARATIVE LANGUAGE AND LITERATURE', 0.76432029),
#  ('MISCELLANEOUS EDUCATION', 0.718364766),
#  ('INTERDISCIPLINARY SOCIAL SCIENCES', 0.721865913),
#  ('ECOLOGY', 0.651659908),
#  ('SECONDARY TEACHER EDUCATION', 0.601751825),
#  ('GENERAL MEDICAL AND HEALTH SERVICES', 0.774576624),
#  ('PHILOSOPHY AND RELIGIOUS STUDIES', 0.41680957399999996),
#  ('ART AND MUSIC EDUCATION', 0.6860244000000001),
#  ('ENGLISH LANGUAGE AND LITERATURE', 0.339670982),
#  ('ELEMENTARY EDUCATION', 0.923745479),
#  ('PHYSICAL FITNESS PARKS RECREATION AND LEISURE', 0.6839426190000001),
#  ('LIBERAL ARTS', 0.70089843),
#  ('FILM VIDEO AND PHOTOGRAPHIC ARTS', 0.686992952),
#  ('GENERAL SOCIAL SCIENCES', 0.502846315),
#  ('PLANT SCIENCE AND AGRONOMY', 0.606888545),
#  ('SCIENCE AND COMPUTER TEACHER EDUCATION', 0.423208896),
#  ('PSYCHOLOGY', 0.7799332040000001),
#  ('MUSIC', 0.444582285),
#  ('PHYSICAL AND HEALTH EDUCATION TEACHING', 0.506720763),
#  ('ART HISTORY AND CRITICISM', 0.845934379),
#  ('FINE ARTS', 0.667033853),
#  ('FAMILY AND CONSUMER SCIENCES', 0.7521438840000001),
#  ('SOCIAL WORK', 0.810704147),
#  ('ANIMAL SCIENCES', 0.91093257),
#  ('VISUAL AND PERFORMING ARTS', 0.697384245),
#  ('TEACHER EDUCATION: MULTIPLE LEVELS', 0.798919817),
#  ('MISCELLANEOUS PSYCHOLOGY', 0.90558993),
#  ('HUMAN SERVICES AND COMMUNITY ORGANIZATION', 0.9040745440000001),
#  ('HUMANITIES', 0.745661538),
#  ('THEOLOGY AND RELIGIOUS VOCATIONS', 0.7284946240000001),
#  ('STUDIO ARTS', 0.584776403),
#  ('COSMETOLOGY SERVICES AND CULINARY ARTS', 0.38371900600000003),
#  ('MISCELLANEOUS AGRICULTURE', 0.719974083),
#  ('ANTHROPOLOGY AND ARCHEOLOGY', 0.968953683),
#  ('COMMUNICATION DISORDERS SCIENCES AND SERVICES', 0.7071362370000001),
#  ('EARLY CHILDHOOD EDUCATION', 0.9679981190000001),
#  ('OTHER FOREIGN LANGUAGES', 0.690110675),
#  ('DRAMA AND THEATER ARTS', 0.629504564),
#  ('COMPOSITION AND RHETORIC', 0.666119448),
#  ('ZOOLOGY', 0.637293376),
#  ('EDUCATIONAL PSYCHOLOGY', 0.8170988090000001),
#  ('CLINICAL PSYCHOLOGY', 0.799859056),
#  ('COUNSELING PSYCHOLOGY', 0.798746217),
#  ('LIBRARY SCIENCE', 0.877959927)]

# %% [markdown]
# # 8. Filtering Rows Using WHERE

# %% [markdown]
# **The SQL workflow revolves around translating the question we want to answer to the subset of data we want from the database. To determine which majors had mostly female students, we want the following subset:**
#
# * only the Major columns
# * only the rows where ShareWomen is greater than 0.5 (corresponding to 50%)

# %% [markdown]
# Here are the comparison operators we can use:
#
# * Less than: <
# * Less than or equal to: <=
# * Greater than: >
# * Greater than or equal to: >=
# * Equal to: =
# * Not equal to: != or <>

# %% [markdown]
# ## TODO:
# * Write a SQL query that returns the majors in the recent_grads table where females were a minority.
#   * Only return the Major and ShareWomen columns (in that order).
#   * Return only the values where ShareWomen is less than 0.5.
#   * Don't limit the number of rows returned.

# %%
# %%sql
#
# SELECT Major,ShareWomen
# FROM recent_grads
# WHERE ShareWomen<0.5;
# Out:
#  * sqlite:///jobs.db
# Done.
# [('PETROLEUM ENGINEERING', 0.120564344),
#  ('MINING AND MINERAL ENGINEERING', 0.10185185199999999),
#  ('METALLURGICAL ENGINEERING', 0.153037383),
#  ('NAVAL ARCHITECTURE AND MARINE ENGINEERING', 0.107313196),
#  ('CHEMICAL ENGINEERING', 0.341630502),
#  ('NUCLEAR ENGINEERING', 0.144966965),
#  ('ASTRONOMY AND ASTROPHYSICS', 0.44135557299999995),
#  ('MECHANICAL ENGINEERING', 0.139792801),
#  ('ELECTRICAL ENGINEERING', 0.437846874),
#  ('COMPUTER ENGINEERING', 0.199412643),
#  ('AEROSPACE ENGINEERING', 0.19645025600000002),
#  ('BIOMEDICAL ENGINEERING', 0.11955890300000001),
#  ('MATERIALS SCIENCE', 0.310820285),
#  ('ENGINEERING MECHANICS PHYSICS AND SCIENCE', 0.183985189),
#  ('BIOLOGICAL ENGINEERING', 0.32078431399999996),
#  ('INDUSTRIAL AND MANUFACTURING ENGINEERING', 0.34347321799999997),
#  ('GENERAL ENGINEERING', 0.252959838),
#  ('ARCHITECTURAL ENGINEERING', 0.35044247799999995),
#  ('COURT REPORTING', 0.236062718),
#  ('FOOD SCIENCE', 0.222695002),
#  ('ELECTRICAL ENGINEERING TECHNOLOGY', 0.325091881),
#  ('MATERIALS ENGINEERING AND MATERIALS SCIENCE', 0.292607004),
#  ('MANAGEMENT INFORMATION SYSTEMS AND STATISTICS', 0.278790146),
#  ('CIVIL ENGINEERING', 0.22711794300000002),
#  ('CONSTRUCTION SERVICES', 0.342228811),
#  ('OPERATIONS LOGISTICS AND E-COMMERCE', 0.322222222),
#  ('MISCELLANEOUS ENGINEERING', 0.189970437),
#  ('PUBLIC POLICY', 0.251388889),
#  ('ENGINEERING TECHNOLOGIES', 0.09071250900000001),
#  ('MISCELLANEOUS FINE ARTS', 0.41017964100000004),
#  ('GEOLOGICAL AND GEOPHYSICAL ENGINEERING', 0.32483805),
#  ('FINANCE', 0.355469059),
#  ('ECONOMICS', 0.34082495700000004),
#  ('BUSINESS ECONOMICS', 0.24919024),
#  ('NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL TECHNOLOGIES', 0.430536761),
#  ('ACCOUNTING', 0.253583302),
#  ('MATHEMATICS', 0.24410308100000003),
#  ('PHYSICS', 0.448098678),
#  ('MEDICAL TECHNOLOGIES TECHNICIANS', 0.43429844100000004),
#  ('STATISTICS AND DECISION SCIENCE', 0.281936407),
#  ('ENGINEERING AND INDUSTRIAL MANAGEMENT', 0.174122505),
#  ('MEDICAL ASSISTING SERVICES', 0.178981938),
#  ('COMPUTER PROGRAMMING AND DATA PROCESSING', 0.269193858),
#  ('GENERAL BUSINESS', 0.4179248),
#  ('ARCHITECTURE', 0.321769663),
#  ('INTERNATIONAL BUSINESS', 0.28290282899999997),
#  ('PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTRATION', 0.451464886),
#  ('MOLECULAR BIOLOGY', 0.07745302700000001),
#  ('MISCELLANEOUS BUSINESS & MEDICAL ADMINISTRATION', 0.200022717),
#  ('MISCELLANEOUS ENGINEERING TECHNOLOGIES', 0.0),
#  ('MECHANICAL ENGINEERING RELATED TECHNOLOGIES', 0.377437326),
#  ('INDUSTRIAL AND ORGANIZATIONAL PSYCHOLOGY', 0.43630163299999997),
#  ('PHYSICAL SCIENCES', 0.42692372),
#  ('MILITARY TECHNOLOGIES', 0.429684963),
#  ('ELECTRICAL, MECHANICAL, AND PRECISION TECHNOLOGIES AND PRODUCTION', 0.23244353199999998),
#  ('MARKETING AND MARKETING RESEARCH', 0.382900433),
#  ('POLITICAL SCIENCE AND GOVERNMENT', 0.485929877),
#  ('GEOGRAPHY', 0.473189524),
#  ('COMPUTER ADMINISTRATION MANAGEMENT AND SECURITY', 0.180882718),
#  ('COMPUTER NETWORKING AND TELECOMMUNICATIONS', 0.305004597),
#  ('GEOLOGY AND EARTH SCIENCE', 0.470196865),
#  ('PUBLIC ADMINISTRATION', 0.47646118299999995),
#  ('COMMUNICATIONS', 0.305109489),
#  ('CRIMINAL JUSTICE AND FIRE PROTECTION', 0.125034655),
#  ('COMMERCIAL ART AND GRAPHIC DESIGN', 0.37435562299999997),
#  ('SPECIAL NEEDS EDUCATION', 0.366176878),
#  ('TRANSPORTATION SCIENCES AND TECHNOLOGIES', 0.321296067),
#  ('NEUROSCIENCE', 0.47501047),
#  ('MULTI/INTERDISCIPLINARY STUDIES', 0.495397153),
#  ('ATMOSPHERIC SCIENCES AND METEOROLOGY', 0.124950495),
#  ('EDUCATIONAL ADMINISTRATION AND SUPERVISION', 0.448732309),
#  ('PHILOSOPHY AND RELIGIOUS STUDIES', 0.41680957399999996),
#  ('ENGLISH LANGUAGE AND LITERATURE', 0.339670982),
#  ('SCIENCE AND COMPUTER TEACHER EDUCATION', 0.423208896),
#  ('MUSIC', 0.444582285),
#  ('COSMETOLOGY SERVICES AND CULINARY ARTS', 0.38371900600000003)]

# %% [markdown]
# # 9. Expressing Multiple Filter Criteria Using 'AND'

# %% [markdown]
# We can also use the AND operator to combine multiple filter criteria

# %% [markdown]
# ## TODO:
# * Write a SQL query that returns all majors that had a majority of female students and a median salary greater than 50000.
#   * Only include the following columns in the results and in this order:
# Major,
# Major_category,
# Median,
# ShareWomen,
#   * Return only the values where ShareWomen is greater than 0.5 and Median is greater than 50000.

# %%
# %%sql
#
# SELECT Major,Major_category,Median,Sharewomen
# FROM recent_grads
# WHERE ShareWomen>0.5
# AND Median>50000;
# Out:
#  * sqlite:///jobs.db
# Done.
# [('ACTUARIAL SCIENCE', 'Business', 62000, 0.535714286),
#  ('COMPUTER SCIENCE', 'Computers & Mathematics', 53000, 0.578766338)]

# %% [markdown]
# # 10. Returning One of Several Conditions With OR

# %% [markdown]
# ## TODO:
# * Write a SQL query that returns the first 20 majors that either:
#
#   * Have a Median salary greater than or equal to 10,000, or
#   * Have more men that women
#
# * Only include the following columns in the results and in this order:
#
#     Major,
# Median,
# Unemployed

# %%
# %%sql
#
# SELECT Major,Median,Unemployed
# FROM recent_grads
# WHERE Median>=10000
# OR Men>Women
# LIMIT 20;
# Out:
#  * sqlite:///jobs.db
# Done.
# [('PETROLEUM ENGINEERING', 110000, 37),
#  ('MINING AND MINERAL ENGINEERING', 75000, 85),
#  ('METALLURGICAL ENGINEERING', 73000, 16),
#  ('NAVAL ARCHITECTURE AND MARINE ENGINEERING', 70000, 40),
#  ('CHEMICAL ENGINEERING', 65000, 1672),
#  ('NUCLEAR ENGINEERING', 65000, 400),
#  ('ACTUARIAL SCIENCE', 62000, 308),
#  ('ASTRONOMY AND ASTROPHYSICS', 62000, 33),
#  ('MECHANICAL ENGINEERING', 60000, 4650),
#  ('ELECTRICAL ENGINEERING', 60000, 3895),
#  ('COMPUTER ENGINEERING', 60000, 2275),
#  ('AEROSPACE ENGINEERING', 60000, 794),
#  ('BIOMEDICAL ENGINEERING', 60000, 1019),
#  ('MATERIALS SCIENCE', 60000, 78),
#  ('ENGINEERING MECHANICS PHYSICS AND SCIENCE', 58000, 23),
#  ('BIOLOGICAL ENGINEERING', 57100, 589),
#  ('INDUSTRIAL AND MANUFACTURING ENGINEERING', 57000, 699),
#  ('GENERAL ENGINEERING', 56000, 2859),
#  ('ARCHITECTURAL ENGINEERING', 54000, 170),
#  ('COURT REPORTING', 54000, 11)]

# %% [markdown]
# # 11. Grouping Operators With Parentheses

# %% [markdown]
# ## TODO:
# * Run the query we explored above, which returns all majors that:
#
#   * Fell under the category of Engineering and either
#
#   * Had mostly women graduates
#   * Or had an unemployment rate below 5.1%, which was the rate in August 2015
# * Only include the following columns in the results and in this order:
#
#   * Major
#   * Major_category
#   * ShareWomen
#   * Unemployment_rate

# %%
# %%sql
#
# SELECT Major,Major_category,ShareWomen,Unemployment_rate
# FROM recent_grads
# WHERE (Major_category=='Engineering')
# AND (ShareWomen>0.5 OR Unemployment_rate<0.051);
# Out:
#  * sqlite:///jobs.db
# Done.
# [('PETROLEUM ENGINEERING', 'Engineering', 0.120564344, 0.018380527),
#  ('METALLURGICAL ENGINEERING', 'Engineering', 0.153037383, 0.024096386),
#  ('NAVAL ARCHITECTURE AND MARINE ENGINEERING', 'Engineering', 0.107313196, 0.050125313),
#  ('MATERIALS SCIENCE', 'Engineering', 0.310820285, 0.023042836),
#  ('ENGINEERING MECHANICS PHYSICS AND SCIENCE', 'Engineering', 0.183985189, 0.006334343),
#  ('INDUSTRIAL AND MANUFACTURING ENGINEERING', 'Engineering', 0.34347321799999997, 0.042875544),
#  ('MATERIALS ENGINEERING AND MATERIALS SCIENCE', 'Engineering', 0.292607004, 0.027788805),
#  ('ENVIRONMENTAL ENGINEERING', 'Engineering', 0.558548009, 0.093588575),
#  ('INDUSTRIAL PRODUCTION TECHNOLOGIES', 'Engineering', 0.75047259, 0.028308097),
#  ('ENGINEERING AND INDUSTRIAL MANAGEMENT', 'Engineering', 0.174122505, 0.03365166)]

# %% [markdown]
# # 12. Ordering Results Using ORDER BY

# %% [markdown]
# ## TODO:
# * Write a query that returns all majors where:
#
#    * ShareWomen is greater than 0.3
#    * And Unemployment_rate is less than .1
#
# * Only include the following columns in the results and in this order:
#
#    Major,
# ShareWomen,
# Unemployment_rate
# * Order the results in descending order by the ShareWomen column.

# %%
# %%sql
#
#
# SELECT Major,ShareWomen,Unemployment_rate
# FROM recent_grads
# WHERE ShareWomen>0.3
# AND Unemployment_rate<1
# ORDER BY ShareWomen DESC
# Out:
#  * sqlite:///jobs.db
# Done.
# [('ANTHROPOLOGY AND ARCHEOLOGY', 0.968953683, 0.102791571),
#  ('EARLY CHILDHOOD EDUCATION', 0.9679981190000001, 0.040104981),
#  ('MATHEMATICS AND COMPUTER SCIENCE', 0.927807246, 0.0),
#  ('ELEMENTARY EDUCATION', 0.923745479, 0.046585715),
#  ('ANIMAL SCIENCES', 0.91093257, 0.050862499000000005),
#  ('PHYSIOLOGY', 0.9066773370000001, 0.06916280000000001),
#  ('MISCELLANEOUS PSYCHOLOGY', 0.90558993, 0.05190783),
#  ('HUMAN SERVICES AND COMMUNITY ORGANIZATION', 0.9040745440000001, 0.037819026),
#  ('NURSING', 0.896018988, 0.04486272400000001),
#  ('GEOSCIENCES', 0.881293889, 0.024373731000000003),
#  ('LIBRARY SCIENCE', 0.877959927, 0.10494571800000001),
#  ('MASS MEDIA', 0.8772275279999999, 0.089836827),
#  ('COMMUNICATION TECHNOLOGIES', 0.8644560790000001, 0.11951146900000001),
#  ('COGNITIVE SCIENCE AND BIOPSYCHOLOGY', 0.854523227, 0.075236167),
#  ('ART HISTORY AND CRITICISM', 0.845934379, 0.060298284),
#  ('EDUCATIONAL PSYCHOLOGY', 0.8170988090000001, 0.065112187),
#  ('GENERAL EDUCATION', 0.8128766059999999, 0.057359929000000004),
#  ('SOCIAL WORK', 0.810704147, 0.06882792),
#  ('CLINICAL PSYCHOLOGY', 0.799859056, 0.14904819800000002),
#  ('TEACHER EDUCATION: MULTIPLE LEVELS', 0.798919817, 0.03654583),
#  ('COUNSELING PSYCHOLOGY', 0.798746217, 0.053620645999999994),
#  ('MATHEMATICS TEACHER EDUCATION', 0.792095262, 0.016202835),
#  ('PSYCHOLOGY', 0.7799332040000001, 0.083810867),
#  ('GENERAL MEDICAL AND HEALTH SERVICES', 0.774576624, 0.082101621),
#  ('HEALTH AND MEDICAL ADMINISTRATIVE SERVICES', 0.770901106, 0.089626262),
#  ('SOIL SCIENCE', 0.764426528, 0.0),
#  ('LINGUISTICS AND COMPARATIVE LANGUAGE AND LITERATURE', 0.76432029, 0.10443571),
#  ('AREA ETHNIC AND CIVILIZATION STUDIES', 0.758060269, 0.063429289),
#  ('APPLIED MATHEMATICS', 0.75392736, 0.09082330699999999),
#  ('FAMILY AND CONSUMER SCIENCES', 0.7521438840000001, 0.067128194),
#  ('INDUSTRIAL PRODUCTION TECHNOLOGIES', 0.75047259, 0.028308097),
#  ('SOCIAL PSYCHOLOGY', 0.7475609259999999, 0.029649596),
#  ('HUMANITIES', 0.745661538, 0.068584071),
#  ('HOSPITALITY MANAGEMENT', 0.733991928, 0.061169193),
#  ('SOCIAL SCIENCE OR HISTORY TEACHER EDUCATION', 0.733967583, 0.054082940999999995),
#  ('THEOLOGY AND RELIGIOUS VOCATIONS', 0.7284946240000001, 0.062628297),
#  ('FRENCH GERMAN LATIN AND OTHER COMMON FOREIGN LANGUAGE STUDIES', 0.728032591, 0.075566386),
#  ('INTERDISCIPLINARY SOCIAL SCIENCES', 0.721865913, 0.092305816),
#  ('MISCELLANEOUS AGRICULTURE', 0.719974083, 0.05976676400000001),
#  ('JOURNALISM', 0.719858952, 0.069176442),
#  ('MISCELLANEOUS EDUCATION', 0.718364766, 0.059211951),
#  ('COMPUTER AND INFORMATION SYSTEMS', 0.7077185020000001, 0.093460326),
#  ('COMMUNICATION DISORDERS SCIENCES AND SERVICES', 0.7071362370000001, 0.047583999999999994),
#  ('MISCELLANEOUS HEALTH MEDICAL PROFESSIONS', 0.702020202, 0.08141125),
#  ('LIBERAL ARTS', 0.70089843, 0.078267592),
#  ('VISUAL AND PERFORMING ARTS', 0.697384245, 0.102197419),
#  ('FORESTRY', 0.690365288, 0.096725743),
#  ('OTHER FOREIGN LANGUAGES', 0.690110675, 0.107115726),
#  ('OCEANOGRAPHY', 0.688999173, 0.056994819),
#  ('FILM VIDEO AND PHOTOGRAPHIC ARTS', 0.686992952, 0.10577224),
#  ('ART AND MUSIC EDUCATION', 0.6860244000000001, 0.038637747),
#  ('PHYSICAL FITNESS PARKS RECREATION AND LEISURE', 0.6839426190000001, 0.051467273),
#  ('ADVERTISING AND PUBLIC RELATIONS', 0.6731433920000001, 0.06796076599999999),
#  ('HUMAN RESOURCES AND PERSONNEL MANAGEMENT', 0.672161443, 0.059569649),
#  ('MULTI-DISCIPLINARY OR GENERAL SCIENCE', 0.669998505, 0.055806815),
#  ('FINE ARTS', 0.667033853, 0.084186296),
#  ('COMPOSITION AND RHETORIC', 0.666119448, 0.081742207),
#  ('COMMUNITY AND PUBLIC HEALTH', 0.6521298170000001, 0.112144387),
#  ('HISTORY', 0.651741294, 0.09566691199999999),
#  ('ECOLOGY', 0.651659908, 0.054475193),
#  ('GENETICS', 0.643331121, 0.034117647),
#  ('TREATMENT THERAPY PROFESSIONS', 0.64, 0.059821207),
#  ('NUTRITION SCIENCES', 0.63814682, 0.068700676),
#  ('ZOOLOGY', 0.637293376, 0.04632028),
#  ('INTERNATIONAL RELATIONS', 0.632986838, 0.09679894300000001),
#  ('UNITED STATES HISTORY', 0.6307163179999999, 0.047179487),
#  ('DRAMA AND THEATER ARTS', 0.629504564, 0.07754113),
#  ('CRIMINOLOGY', 0.618223028, 0.097243919),
#  ('MICROBIOLOGY', 0.615727227, 0.066775872),
#  ('PLANT SCIENCE AND AGRONOMY', 0.606888545, 0.045454545),
#  ('BIOLOGY', 0.601858152, 0.070724732),
#  ('SECONDARY TEACHER EDUCATION', 0.601751825, 0.05222898),
#  ('AGRICULTURE PRODUCTION AND MANAGEMENT', 0.59420765, 0.050030835999999995),
#  ('PRE-LAW AND LEGAL STUDIES', 0.591001011, 0.07196501599999999),
#  ('AGRICULTURAL ECONOMICS', 0.589711902, 0.077249576),
#  ('STUDIO ARTS', 0.584776403, 0.089552239),
#  ('ENVIRONMENTAL SCIENCE', 0.584556133, 0.07858468099999999),
#  ('BUSINESS MANAGEMENT AND ADMINISTRATION', 0.580948004, 0.07221834099999999),
#  ('COMPUTER SCIENCE', 0.578766338, 0.063172771),
#  ('LANGUAGE AND DRAMA EDUCATION', 0.576360061, 0.050306435),
#  ('MISCELLANEOUS BIOLOGY', 0.566640502, 0.058545455),
#  ('SCHOOL STUDENT COUNSELING', 0.56486557, 0.10757946199999999),
#  ('NATURAL RESOURCES MANAGEMENT', 0.564639335, 0.066619195),
#  ('ENVIRONMENTAL ENGINEERING', 0.558548009, 0.093588575),
#  ('HEALTH AND MEDICAL PREPARATORY PROGRAMS', 0.5566037739999999, 0.06977971200000001),
#  ('MISCELLANEOUS SOCIAL SCIENCES', 0.5434054220000001, 0.073079538),
#  ('ACTUARIAL SCIENCE', 0.535714286, 0.095652174),
#  ('SOCIOLOGY', 0.532333788, 0.084951001),
#  ('BOTANY', 0.52896915, 0.0),
#  ('INFORMATION SCIENCES', 0.526475764, 0.060741445),
#  ('PHARMACOLOGY', 0.524152583, 0.085531575),
#  ('GENERAL AGRICULTURE', 0.515543329, 0.019642463),
#  ('BIOCHEMICAL SCIENCES', 0.515406449, 0.080531385),
#  ('INTERCULTURAL AND INTERNATIONAL STUDIES', 0.507376968, 0.083633531),
#  ('PHYSICAL AND HEALTH EDUCATION TEACHING', 0.506720763, 0.074667496),
#  ('CHEMISTRY', 0.5051405379999999, 0.053972400000000004),
#  ('GENERAL SOCIAL SCIENCES', 0.502846315, 0.103454715),
#  ('MULTI/INTERDISCIPLINARY STUDIES', 0.495397153, 0.070860927),
#  ('POLITICAL SCIENCE AND GOVERNMENT', 0.485929877, 0.101174601),
#  ('PUBLIC ADMINISTRATION', 0.47646118299999995, 0.15949059999999998),
#  ('NEUROSCIENCE', 0.47501047, 0.048481675),
#  ('GEOGRAPHY', 0.473189524, 0.113458628),
#  ('GEOLOGY AND EARTH SCIENCE', 0.470196865, 0.075448568),
#  ('PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTRATION', 0.451464886, 0.055520827),
#  ('EDUCATIONAL ADMINISTRATION AND SUPERVISION', 0.448732309, 0.0),
#  ('PHYSICS', 0.448098678, 0.048224496),
#  ('MUSIC', 0.444582285, 0.075959674),
#  ('ASTRONOMY AND ASTROPHYSICS', 0.44135557299999995, 0.021167415),
#  ('ELECTRICAL ENGINEERING', 0.437846874, 0.059173845),
#  ('INDUSTRIAL AND ORGANIZATIONAL PSYCHOLOGY', 0.43630163299999997, 0.10878661099999999),
#  ('MEDICAL TECHNOLOGIES TECHNICIANS', 0.43429844100000004, 0.03698279),
#  ('NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL TECHNOLOGIES', 0.430536761, 0.07154047),
#  ('PHYSICAL SCIENCES', 0.42692372, 0.035353535),
#  ('SCIENCE AND COMPUTER TEACHER EDUCATION', 0.423208896, 0.047263682),
#  ('GENERAL BUSINESS', 0.4179248, 0.072861468),
#  ('PHILOSOPHY AND RELIGIOUS STUDIES', 0.41680957399999996, 0.096051684),
#  ('MISCELLANEOUS FINE ARTS', 0.41017964100000004, 0.089375),
#  ('COSMETOLOGY SERVICES AND CULINARY ARTS', 0.38371900600000003, 0.055676856),
#  ('MARKETING AND MARKETING RESEARCH', 0.382900433, 0.061215064000000007),
#  ('MECHANICAL ENGINEERING RELATED TECHNOLOGIES', 0.377437326, 0.056357078),
#  ('COMMERCIAL ART AND GRAPHIC DESIGN', 0.37435562299999997, 0.096797577),
#  ('SPECIAL NEEDS EDUCATION', 0.366176878, 0.041507819),
#  ('FINANCE', 0.355469059, 0.060686356),
#  ('ARCHITECTURAL ENGINEERING', 0.35044247799999995, 0.061930782999999996),
#  ('INDUSTRIAL AND MANUFACTURING ENGINEERING', 0.34347321799999997, 0.042875544),
#  ('CONSTRUCTION SERVICES', 0.342228811, 0.060023041),
#  ('CHEMICAL ENGINEERING', 0.341630502, 0.061097712),
#  ('ECONOMICS', 0.34082495700000004, 0.099092317),
#  ('ENGLISH LANGUAGE AND LITERATURE', 0.339670982, 0.08772359),
#  ('ELECTRICAL ENGINEERING TECHNOLOGY', 0.325091881, 0.087557114),
#  ('GEOLOGICAL AND GEOPHYSICAL ENGINEERING', 0.32483805, 0.075038285),
#  ('OPERATIONS LOGISTICS AND E-COMMERCE', 0.322222222, 0.047858702999999995),
#  ('ARCHITECTURE', 0.321769663, 0.113331949),
#  ('TRANSPORTATION SCIENCES AND TECHNOLOGIES', 0.321296067, 0.072724524),
#  ('BIOLOGICAL ENGINEERING', 0.32078431399999996, 0.087143069),
#  ('MATERIALS SCIENCE', 0.310820285, 0.023042836),
#  ('COMMUNICATIONS', 0.305109489, 0.07517697599999999),
#  ('COMPUTER NETWORKING AND TELECOMMUNICATIONS', 0.305004597, 0.151849807)]

# %% [markdown]
# # 13. Practice Writing a Query

# %% [markdown]
# **Which engineering majors had the highest full time employment rates?**

# %%
# %%sql
#
# SELECT Major_category, Major, Unemployment_rate
# FROM recent_grads
# WHERE Major_category='Engineering'
# OR Major_category='Physical Sciences'
# ORDER BY Unemployment_rate;
# Out:
#  * sqlite:///jobs.db
# Done.
# [('Engineering', 'ENGINEERING MECHANICS PHYSICS AND SCIENCE', 0.006334343),
#  ('Engineering', 'PETROLEUM ENGINEERING', 0.018380527),
#  ('Physical Sciences', 'ASTRONOMY AND ASTROPHYSICS', 0.021167415),
#  ('Physical Sciences', 'ATMOSPHERIC SCIENCES AND METEOROLOGY', 0.022228555),
#  ('Engineering', 'MATERIALS SCIENCE', 0.023042836),
#  ('Engineering', 'METALLURGICAL ENGINEERING', 0.024096386),
#  ('Physical Sciences', 'GEOSCIENCES', 0.024373731000000003),
#  ('Engineering', 'MATERIALS ENGINEERING AND MATERIALS SCIENCE', 0.027788805),
#  ('Engineering', 'INDUSTRIAL PRODUCTION TECHNOLOGIES', 0.028308097),
#  ('Engineering', 'ENGINEERING AND INDUSTRIAL MANAGEMENT', 0.03365166),
#  ('Physical Sciences', 'PHYSICAL SCIENCES', 0.035353535),
#  ('Engineering', 'INDUSTRIAL AND MANUFACTURING ENGINEERING', 0.042875544),
#  ('Physical Sciences', 'PHYSICS', 0.048224496),
#  ('Engineering', 'NAVAL ARCHITECTURE AND MARINE ENGINEERING', 0.050125313),
#  ('Engineering', 'MISCELLANEOUS ENGINEERING TECHNOLOGIES', 0.05253852),
#  ('Physical Sciences', 'CHEMISTRY', 0.053972400000000004),
#  ('Engineering', 'ENGINEERING TECHNOLOGIES', 0.055030385),
#  ('Physical Sciences', 'MULTI-DISCIPLINARY OR GENERAL SCIENCE', 0.055806815),
#  ('Engineering', 'MECHANICAL ENGINEERING RELATED TECHNOLOGIES', 0.056357078),
#  ('Physical Sciences', 'OCEANOGRAPHY', 0.056994819),
#  ('Engineering', 'MECHANICAL ENGINEERING', 0.057342277999999997),
#  ('Engineering', 'ELECTRICAL ENGINEERING', 0.059173845),
#  ('Engineering', 'GENERAL ENGINEERING', 0.059824231),
#  ('Engineering', 'CHEMICAL ENGINEERING', 0.061097712),
#  ('Engineering', 'ARCHITECTURAL ENGINEERING', 0.061930782999999996),
#  ('Engineering', 'AEROSPACE ENGINEERING', 0.065162085),
#  ('Engineering', 'COMPUTER ENGINEERING', 0.065409275),
#  ('Engineering', 'CIVIL ENGINEERING', 0.07060957400000001),
#  ('Physical Sciences', 'NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL TECHNOLOGIES', 0.07154047),
#  ('Engineering', 'MISCELLANEOUS ENGINEERING', 0.074392523),
#  ('Engineering', 'GEOLOGICAL AND GEOPHYSICAL ENGINEERING', 0.075038285),
#  ('Physical Sciences', 'GEOLOGY AND EARTH SCIENCE', 0.075448568),
#  ('Engineering', 'BIOLOGICAL ENGINEERING', 0.087143069),
#  ('Engineering', 'ELECTRICAL ENGINEERING TECHNOLOGY', 0.087557114),
#  ('Engineering', 'BIOMEDICAL ENGINEERING', 0.09208386),
#  ('Engineering', 'ENVIRONMENTAL ENGINEERING', 0.093588575),
#  ('Engineering', 'ARCHITECTURE', 0.113331949),
#  ('Engineering', 'MINING AND MINERAL ENGINEERING', 0.117241379),
#  ('Engineering', 'NUCLEAR ENGINEERING', 0.177226407)]

# %% [markdown]
# In this mission, we became familiar with a dataset stored in a SQLite table by learning how to craft basic SQL queries. The kind of queries we learned here and that we'll keep studying for the next few courses are one of four types of SQL commands we can give:

# %% [markdown]
# [Data query language](https://en.wikipedia.org/wiki/Data_query_language)
#
# [Data definition language](https://en.wikipedia.org/wiki/Data_definition_language)
#
# [Data control language](https://en.wikipedia.org/wiki/Data_control_language)
#
# [Data manipulation language](https://en.wikipedia.org/wiki/Data_manipulation_language)
