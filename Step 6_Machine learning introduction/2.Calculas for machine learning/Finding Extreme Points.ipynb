# %% [markdown]
# # 1. Recap

# %% [markdown]
# * In the last mission, we learned `how to use limits to calculate the point a function approaches when the input value approaches a specific value.`

# %% [markdown]
# As x varies, the plot on the left **visualizes how the tangent line for the curve changes** while the plot on the right **visualizes how the slope of this tangent line changes.**

# %%
from IPython.display import Image
with open('C:/Users/krishna/Desktop/Github repos/Data-Scientist-In-Python/Step 6_Machine learning introduction/2.Calculas for machine learning/tangent_slope-view.gif ','rb') as f:
    display(Image(data=f.read(), format='gif'))

# %% [markdown]
# By plotting the slopes at many different x values , we can tell that they follow a straight line. This line can be described as its own function, and is known as the derivative. `A function's derivative can tell us the slope of the tangent line for any  value along the function.`

# %% [markdown]
# # 2. Introduction To Derivatives

# %%
from IPython.display import Image
with open('C:/Users/krishna/Desktop/Github repos/Data-Scientist-In-Python/Step 6_Machine learning introduction/2.Calculas for machine learning/slope_h_form.gif ','rb') as f:
    display(Image(data=f.read(), format='gif'))

# %% [markdown]
# Let's first start by rewriting the slope equation to the more common form. Instead of using x1 and x2 in the slope equation, let's` use x and x+h` .

# %% [markdown]
# $\lim_{h \to 0} \frac{f(x + h) - f(x)}{h} $

# %% [markdown]
# # 3. Differentiation

# %% [markdown]
# **The process of finding a function's derivative is known as differentiation.**

# %% [markdown]
# ## $\lim_{h \to 0} \frac{(-(x + h)^2 + 3(x + h) - 1) - (-(x)^2 + 3x - 1)}{h}$

# %% [markdown]
# Once we cancel the  on both the numerator and the denominator, we finally get a defined limit.

# %% [markdown]
# $\lim_{h \to 0} -2x - h + 3$

# %% [markdown]
# ## TODO:
# * Simplify the equation by using direct substitution to solve the limit.
# * Use numpy.linspace() to generate 110 values from -5 to 6 and assign to x.
# * Transform x using the equation you just solved and assign to y.
# * Generate a line plot using x and y.

# %%
import sympy
x,h=sympy.symbols('x h')
final_eq=sympy.limit(-2*x-h+3,h,0)
print(final_eq)
# Out:
# -2*x + 3

# %%
import numpy as np 
import matplotlib.pyplot as plt

x=np.linspace(-5,6,110)
y=-2*x+3
plt.plot(x,y)

# %% [markdown]
# We use the following notation to specify that **-2*x+3  is our curve's derivative**:

# %% [markdown]
# $y' = -2x + 3$

# %% [markdown]
# $f'(x) = -2x + 3$

# %% [markdown]
# $\frac{d}{dx}[ -x^2 + 3x - 1 ] =  -2x + 3$

# %% [markdown]
# * All of three are notations for functions derivative

# %% [markdown]
# # 4. Critical Points

# %% [markdown]
# **At a function's critical point, the slope is either 0 or undefined.**` Not all critical points act as transition points for slopes,` however.
# * The following image visualizes the slope for $y=x^3$ and lets you explore how the slope changes before and after the critical point. You'll notice how the slope remains positive before and after the critical point.

# %%
from IPython.display import Image
with open('C:/Users/krishna/Desktop/Github repos/Data-Scientist-In-Python/Step 6_Machine learning introduction/2.Calculas for machine learning/critical_points.gif ','rb') as f:
    display(Image(data=f.read(), format='gif'))

# %% [markdown]
# # 5. Extreme Values

# %% [markdown]
# From above we observed how the slope didn't change from positive to negative at the critical point.

# %% [markdown]
# `Critical points are interesting to us in data science when they represent extreme values`.

# %% [markdown]
# **Extreme values can be split into 2 categories -- minimum and maximum.**
#
# * A critical point can be a minimum value if the slope transitions from negative to positive at that point.
# * When the slope transitions from positive to negative at a point, it can be a maximum value.

# %%
from IPython.display import Image
Image(filename='C:/Users/krishna/Desktop/Github repos/Data-Scientist-In-Python/Step 6_Machine learning introduction/2.Calculas for machine learning/curve_three_critical_points.png')

# %% [markdown]
# **A curve can have multiple critical points and multiple candidates for minimum and maximum values**. The following curve has 3 critical points and all 3 meet the criteria of transitioning slope from positive to negative or negative to positive. At the same time, none of the values are the highest points on the curve (while one of them seems to be the lowest).

# %%
from IPython.display import Image
Image(filename='C:/Users/krishna/Desktop/Github repos/Data-Scientist-In-Python/Step 6_Machine learning introduction/2.Calculas for machine learning/curve_three_critical_points_relative_minmax.png')

# %% [markdown]
# These values are known as local extrema, since they're the lowest or highest value in the interval surrounding each point. If a critical point is the lowest point in the interval surrounding it, it's known as a **relative minimum.** If it's the highest point in the neighborhood, it's known as a **relative maximum.**

# %% [markdown]
# # 6. Power Rule

# %% [markdown]
# We calculated the derivative for our curve using a limit and working out the arithmetic. We then set the derivative function to  $0$ and calculated the critical points. This approach can be painful to do for more complex functions like $y = x^5 - x$ because we'll need to replace $x$ with $x+h$ and expand the exponent :$(x+h)^5$
#
# $f'(x) = \lim_{h \to 0} \frac{((x + h)^5 - (x + h)) - (x^5 - x) }{h}$

# %% [markdown]
# **We can instead apply derivative rules to more easily calculate the derivative function.**

# %% [markdown]
# ### Power Rule:
# ## $f'(x) = r x^{r-1}$

# %% [markdown]
# ## TODO:
# * Calculate the derivative of $f(x) = x^5$ using pencil and paper. Use the derivative function to look up the slope at $x=2$ and assign to slope_one.
# * Calculate the derivative of $f(x)=x^9$ using pencil and paper. Use the derivative function to look up the slope at $x=0$ and assign to slope_two.

# %%
slope_one=5*(2)**4
slope_one
# Out:
# 80

# %%
slope_two=9*(0)**8
slope_two
# Out:
# 0

# %% [markdown]
# # 7. Linearity Of Differentiation

# %% [markdown]
# Another important set of rules is linearity of differentiation.

# %% [markdown]
# **Linearity of differentiation consists of 2 rules. First is the sum rule:**
#
# ## $\frac {d}{dx} [f(x) + g(x)] = \frac {d}{dx} [f(x)] + \frac {d}{dx} [g(x)]$

# %% [markdown]
# **Second is the constant factor rule, which lets us pull out constants from the derivative:**

# %% [markdown]
# ## $\frac {d}{dx} [cf(x)] = c\frac {d}{dx} [f(x)]$

# %% [markdown]
# ## TODO:
# * Calculate the derivative of $f(x)=x^5-x$ using pencil and paper. Use the derivative function to look up the slope at $x=1$ and assign to slope_three.
# * Calculate the derivative of $f(x)=x^3-x^2$ using pencil and paper. Use the derivative function to look up the slope at $x=2$ and assign to slope_four.

# %%
slope_three=5*(1)**4-1
slope_three
# Out:
# 4

# %%
slope_four=3*(2)**2-2*(2)
slope_four
# Out:
# 8

# %% [markdown]
# # 8. Practicing Finding Extreme Values

# %% [markdown]
# ##  TODO:
# Find the critical points for $f(x)=x^3-x^2$ .
# * Create 2 empty lists and assign to rel_min and rel_max.
# * If a critical point is a relative minimum, add it to the list rel_min.
# * If a critical point is a relative maximum, add it to the list rel_max.

# %% [markdown]
# **To analyze the direction of the slope, we use a [sign chart](http://www.rasmus.is/uk/t/F/Su53k02.htm).** With a sign chart, we only care about if a given point in a region comes out positive or negative. This tool makes it great to analyze the direction of the slope (positive or negative).

# %%
# f'(x)=3*x**2-2x
critical_points=[0,2/3]
rel_min=[2/3]
rel_max=[0]
