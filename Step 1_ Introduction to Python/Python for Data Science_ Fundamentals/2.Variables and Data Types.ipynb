# %% [markdown]
# ## 1. Save values
# * The storage location to which we saved 20 has a unique identifier, and we can use it to access 20. The identifier is named result

# %%
print(5*2+5)
result=5*2+5 # saved 
print(result)
# Out:
# 15
# 15

# %% [markdown]
# ## 2. Variables
# * The storage location for 20 is more commonly known as a **variable**. When we ran the code result = 20, we stored 20 in a **variable (storage location)**named result — so result is a **variable name.**

# %%
a_value=15
print(a_value)
a_result=(25-7)*17
print(a_result + 12)
print(a_value + a_result)
a_value=15
a_result=(25 - 7)*17
print(a_value)
print(a_result+12)
print(a_value+a_result)
# Out:
# 15
# 318
# 321
# 15
# 318
# 321

# %% [markdown]
# ## 3. Variable names
# * These are the two syntax rules we need to be aware of when we're naming variables:
#
# * We must use only letters, numbers, or underscores (we can't use apostrophes, hyphens, whitespace characters, etc.).
# * Variable names cannot start with a number.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * variable names are **case sensitive**

# %% [markdown]
# ## 4. Updating Variables

# %%
income = 34000 
income=income+6000     # income variable is getting updated
print(income)
# Out:
# 40000

# %% [markdown]
# ## 5. Syntax Shortcuts

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *  Whenever the syntax is correct but the computer still returns an error for one reason or another, it's called a **runtime error.**
# * When we try to update a variable that we haven't defined, we get an error called **NameError**. Its is runtime error.

# %%
variable_1=20
variable_2=20
variable_2 +=10
variable_1 *=4
print(variable_1)
print(variable_2)
# Out:
# 80
# 30

# %% [markdown]
# ## 6. Integers and Floats
# * In computer programming, values are classified into different **types, or data types**
# * Depending on the type, the computer will know `how to store a value in memory`, or `what operations can and can't be performed on a value.`

# %%
print(type(3))
type(5.3)
# Out:
# <class 'int'>
# float

# %% [markdown]
# ## 7. Conversion Between Types
# * It's possible to convert a float to an integer and vice versa
# * running the round() command doesn't change the value stored by a variable unless we assign the rounded value back to the variable:

# %%
variable_a=13.9
variable_b=2.8
variable_a=round(variable_a)
variable_b=int(variable_b)
print(variable_a)
print(variable_b)
# Out:
# 14
# 2

# %% [markdown]
# ## 8. Strings
# * In programming, we call sequences of characters like "Facebook", "USD", or "dasdaslkj" strings. In Python, a string is of the str type:
# * 'this' and "this" both are same.

# %%
app_name="Pandora - Music & Radio"
average_rating='4.0'
total_ratings='1724546'
price='free'
print(app_name)
# Out:
# Pandora - Music & Radio

# %% [markdown]
# ## 9. . Escaping Special Characters
# * The \ character has a special function within a string: it escapes (cancels) the special function of characters. Above, we used \ to escape the second single quotation mark, which had the special function of ending the string.
# *  alternate double quotation marks (" ") with single quotation marks (' '):

# %%
motto='Facebook\'s new motto is "move fast with stable infra."'
print(motto)
print("Facebooks's new motto is 'move fast with satble infra.'")
# Out:
# Facebook's new motto is "move fast with stable infra."
# Facebooks's new motto is 'move fast with satble infra.'

# %% [markdown]
# ## 10.String Operations
# * The process of linking two or more strings together is called concatenation.
# * It's also possible to concatenate a string with one or more copies of itself using the * operator, followed by a number which   specifies the number of times the string has to be multiplied:
# *

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('an' * 2 )
print('a'*0)      # no output
print('an'*-1)    # no output

print("an  "*4)   # introduce gap
# Out:
# anan
#
#
# an  an  an  an

# %%
facebook="Facebook's rating is"
fb_rating=3.5
fb_rating_str=str(fb_rating)
fb=facebook +  fb_rating_str
print(fb)
# Out:
# Facebook's rating is3.5

# %% [markdown]
# **Using triple quotation marks also allows us to use both single and double quotation marks without needing to escape them.**
